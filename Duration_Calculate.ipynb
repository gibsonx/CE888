# %% [markdown]
# <a href="https://colab.research.google.com/github/gibsonx/CE888/blob/master/Duration_Calculate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install waterfallcharts

# %%
import matplotlib.pyplot as plt
import waterfall_chart
from matplotlib import transforms

# %%
#Data Perfered
a = ['Worker02 C=0.93','Worker03 C=0.43','Worker04 C=0.42','Worker05 C=0.40']
b = [15.8,10.3,9.4,8.9]
waterfall_chart.plot(a, b,sorted_value=True,net_label='SUM',threshold=0.5,y_lab="Time (Second)",x_lab="Workers Sequence",blue_color="blue")
plt.xticks(fontsize=12)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text major ticklabel objects>)

# %%
a = ['Worker05','Worker04','Worker05','Worker04']
b = [9.4,8.9,9.4,8.9]
waterfall_chart.plot(a, b,net_label='SUM',y_lab="Time (Second)",x_lab="Workers Sequence",blue_color="blue")
plt.xticks(fontsize=12)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text major ticklabel objects>)

# %%
a = ['Worker01 C=0.90','Worker02 C=0.42','Worker03 C=0.40','Worker04 C=0.40']
b = [6.5,10.2,8.9,8.9]
waterfall_chart.plot(a, b,net_label='SUM',threshold=0.5,y_lab="Time (Second)",x_lab="Workers Sequence",blue_color="blue")
plt.xticks(fontsize=12)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text major ticklabel objects>)
