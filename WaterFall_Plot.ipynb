# %% [markdown]
# <a href="https://colab.research.google.com/github/gibsonx/CE888/blob/master/WaterFall_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install waterfallcharts
# Out:
# ...
#   Created wheel for waterfallcharts: filename=waterfallcharts-3.8-py3-none-any.whl size=3413 sha256=571e164c04e5dde089f1b27969607f81240e27fa76957d427ebf52726dd939e1
#   Stored in directory: /root/.cache/pip/wheels/4a/b2/85/9b6eda27fab2effa580c6942fb094e8536cc46e8741ec5f586
# Successfully built waterfallcharts
# ...

# %%
import matplotlib.pyplot as plt
import waterfall_chart
from matplotlib import transforms

# %%
a = ['Worker01 C=0.93','Worker02 C=0.43','Worker03 C=0.42','Worker04 C=0.40']
b = [15.8,11.3,9.4,8.9]
waterfall_chart.plot(a, b,sorted_value=True,net_label='SUM',threshold=0.5,y_lab="Time (Second)",x_lab="Workers",blue_color="blue")
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py'>

# %%
a = ['Worker05','Worker04','Worker05','Worker04']
b = [9.4,8.9,9.4,8.9]
waterfall_chart.plot(a, b,net_label='SUM',y_lab="Time (Second)",x_lab="Workers",blue_color="blue")
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py'>

# %%
a = ['Worker01 C=0.90','Worker02 C=0.42','Worker03 C=0.40','Worker04 C=0.40']
b = [6.5,7.1,8.9,7.1]
waterfall_chart.plot(a, b,net_label='SUM',threshold=0.5,y_lab="Time (Second)",x_lab="Workers",blue_color="blue")
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py'>
